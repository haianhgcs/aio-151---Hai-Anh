# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Titanic data:
#
# * PassengerId: Mã hàng khách. Đây được xem là chỉ mục của bảng dữ liệu.
# * Pclass: Hạng vé tàu của hàng khách.
# * Sex: Giới tính của hàng khách.
# * Age: Tuổi của hàng khách.
# * SibSp: Số lượng anh chị em và/hoặc người yêu đi cùng chuyến tàu với hàng
# khách.
# * Parch: Số lượng phụ huynh và/hoặc con cháu đi cùng chuyến tàu với hàng khách.
# * Fare: Giá vé tàu của hàng khách.
# * Embarked: Cảng xuất phát của hàng khách.
# * Title: Tước hiệu của hàng khách.
# * Survived: Hàng khách có (1) sống sót qua thảm kịch hay không (0)?

# %%
dataset_path = '/content/titanic_modified_dataset.csv'
df = pd.read_csv(dataset_path, index_col='PassengerId')
df.head()
# Out:
#              Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Title  \
# PassengerId
# 1                 3    0  22.0      1      0   7.2500         0      0
# 2                 1    1  38.0      1      0  71.2833         1      1
# 3                 3    1  26.0      0      0   7.9250         0      2
# 4                 1    1  35.0      1      0  53.1000         0      1
# 5                 3    0  35.0      0      0   8.0500         0      0
#
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %% [markdown]
# # Split X, y from data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Split data to array and split into X, y
dataset_arr = df.to_numpy().astype(np.float64)
X, y = dataset_arr[:, :-1], dataset_arr[:, -1]

# %% [markdown]
# # Add bias into X set

# %%
# Add bias into X
intercept = np.ones((X.shape[0], 1))
X_b = np.concatenate((intercept, X), axis=1)

# %% [markdown]
# # Split train, val, test dataset

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Split data into train and test set
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True
X_train, X_val, y_train, y_val = train_test_split(X_b, y, test_size=val_size, random_state=random_state, shuffle=is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle)

# %% [markdown]
# # Standard data
# Ta sử dụng X_train vừa tạo ở bước trên fit vào hàm chuẩn hóa StandardScaler. Sau đó, đem scaler này chuẩn hóa cho tập X_val và X_test (lưu ý rằng ta không chuẩn hóa bias nên sẽ bỏ qua cột đầu tiên trong X):

# %%
normalizer = StandardScaler()
X_train[:, 1:] = normalizer.fit_transform(X_train[:, 1:])
X_val[:, 1:] = normalizer.fit_transform(X_val[:, 1:])
X_test[:, 1:] = normalizer.fit_transform(X_test[:, 1:])

# %% [markdown]
# # Implement importance functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def sigmoid(z):
  return 1 / (1 + np.exp(-z))

# %%
def predict(X, theta):
  dot_product = np.dot(X, theta)
  y_hat = sigmoid(dot_product)

  return y_hat

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def compute_loss(y_hat, y):
  y_hat = np.clip(y_hat, 1e-7, 1 - 1e-7)

  return (-y * np.log(y_hat) - (1 - y) * np.log(1 - y_hat)).mean()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def compute_gradient(X, y, y_hat):
  return np.dot(X.T, (y_hat - y)) / y.size

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def update_theta(theta, gradient, lr):
  return theta - lr * gradient

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def compute_accuracy(X, y, theta):
  y_hat = predict(X, theta).round()
  acc = (y_hat == y).mean()
  return acc

# %% [markdown]
# # Init parameters

# %%
lr = 0.01
epochs = 100
batch_size = 16

np.random.seed(random_state)
theta = np.random.uniform(size=X_train.shape[1])

# %% [markdown]
# # Training model

# %% [markdown]
# Khởi tạo vòng lặp với số lần lặp bằng số epochs. Với mỗi lần lặp, duyệt qua toàn bộ mẫu dữ liệu (trong training set) theo từng bộ mẫu dữ liệu có kích thước **batch_size** (tạm gọi là cặp **X_i** và **y_i**) và thực hiện các bước tính toán sau:
# * (a) Tính **y_hat** sử dụng hàm **predict(X_i, theta)**. Đây là kết quả dự đoán của mô hình với các mẫu dữ liệu tại batch đang xét.
# * (b) Tính **loss** sử dụng hàm **compute_loss(y_hat, y_i)**. Lưu trữ giá trị này vào một list **batch_losses**, dùng cho việc trực quan hóa kết quả huấn luyện sau này.
# * (c) Tính **gradient** sử dụng hàm **compute_gradient(X_i, y_i, y_hat)**.
# * (d) Sử dụng kết quả gradient vừa tìm được để cập nhật bộ trọng số **theta** sử dụng hàm **update_theta(theta, gradient, lr)**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
  train_batch_losses = []
  train_batch_accs = []
  val_batch_losses = []
  val_batch_accs = []

  for i in range(0, X_train.shape[0], batch_size):
    X_i = X_train[i:i+batch_size]
    y_i = y_train[i:i+batch_size]

    # Forward on train data
    y_hat = predict(X_i, theta)
    train_loss = compute_loss(y_hat, y_i)

    # Backward propagation
    gradient = compute_gradient(X_i, y_i, y_hat)
    theta = update_theta(theta, gradient, lr)

    train_batch_losses.append(train_loss)
    train_acc = compute_accuracy(X_train, y_train, theta)
    train_batch_accs.append(train_acc)

    # Apply on validation data
    y_val_hat = predict(X_val, theta)
    val_loss = compute_loss(y_val_hat, y_val)
    val_batch_losses.append(val_loss)

    val_acc = compute_accuracy(X_val, y_val, theta)
    val_batch_accs.append(val_acc)

  train_batch_loss = sum(train_batch_losses) / len(train_batch_losses)
  train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
  val_batch_loss = sum(val_batch_losses) / len(val_batch_losses)
  val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

  train_losses.append(train_batch_loss)
  train_accs.append(train_batch_acc)
  val_losses.append(val_batch_loss)
  val_accs.append(val_batch_acc)

  print(f'\nEPOCH {epoch + 1}: \tTrainning loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:3f}')
# Out:
# EPOCH 1: 	Trainning loss: 0.703	Validation loss: 0.625784
#
# EPOCH 2: 	Trainning loss: 0.670	Validation loss: 0.603953
#
# EPOCH 3: 	Trainning loss: 0.640	Validation loss: 0.585111
#
# EPOCH 4: 	Trainning loss: 0.614	Validation loss: 0.568915
#
# EPOCH 5: 	Trainning loss: 0.592	Validation loss: 0.555073
#
# EPOCH 6: 	Trainning loss: 0.572	Validation loss: 0.543327
#
# EPOCH 7: 	Trainning loss: 0.554	Validation loss: 0.533439
#
# EPOCH 8: 	Trainning loss: 0.539	Validation loss: 0.525187
#
# EPOCH 9: 	Trainning loss: 0.526	Validation loss: 0.518357
#
# EPOCH 10: 	Trainning loss: 0.514	Validation loss: 0.512752
#
# EPOCH 11: 	Trainning loss: 0.504	Validation loss: 0.508185
#
# EPOCH 12: 	Trainning loss: 0.495	Validation loss: 0.504492
#
# EPOCH 13: 	Trainning loss: 0.487	Validation loss: 0.501530
#
# EPOCH 14: 	Trainning loss: 0.480	Validation loss: 0.499175
#
# EPOCH 15: 	Trainning loss: 0.474	Validation loss: 0.497322
#
# EPOCH 16: 	Trainning loss: 0.468	Validation loss: 0.495886
#
# EPOCH 17: 	Trainning loss: 0.463	Validation loss: 0.494793
#
# EPOCH 18: 	Trainning loss: 0.459	Validation loss: 0.493984
#
# EPOCH 19: 	Trainning loss: 0.455	Validation loss: 0.493408
#
# EPOCH 20: 	Trainning loss: 0.452	Validation loss: 0.493026
#
# EPOCH 21: 	Trainning loss: 0.449	Validation loss: 0.492801
#
# EPOCH 22: 	Trainning loss: 0.446	Validation loss: 0.492707
#
# EPOCH 23: 	Trainning loss: 0.443	Validation loss: 0.492719
#
# EPOCH 24: 	Trainning loss: 0.441	Validation loss: 0.492818
#
# EPOCH 25: 	Trainning loss: 0.439	Validation loss: 0.492987
#
# EPOCH 26: 	Trainning loss: 0.437	Validation loss: 0.493213
#
# EPOCH 27: 	Trainning loss: 0.435	Validation loss: 0.493484
#
# EPOCH 28: 	Trainning loss: 0.434	Validation loss: 0.493791
#
# EPOCH 29: 	Trainning loss: 0.432	Validation loss: 0.494125
#
# EPOCH 30: 	Trainning loss: 0.431	Validation loss: 0.494482
#
# EPOCH 31: 	Trainning loss: 0.430	Validation loss: 0.494854
#
# EPOCH 32: 	Trainning loss: 0.429	Validation loss: 0.495238
#
# EPOCH 33: 	Trainning loss: 0.428	Validation loss: 0.495629
#
# EPOCH 34: 	Trainning loss: 0.427	Validation loss: 0.496025
#
# EPOCH 35: 	Trainning loss: 0.426	Validation loss: 0.496422
#
# EPOCH 36: 	Trainning loss: 0.425	Validation loss: 0.496820
#
# EPOCH 37: 	Trainning loss: 0.424	Validation loss: 0.497216
#
# EPOCH 38: 	Trainning loss: 0.424	Validation loss: 0.497608
#
# EPOCH 39: 	Trainning loss: 0.423	Validation loss: 0.497996
#
# EPOCH 40: 	Trainning loss: 0.422	Validation loss: 0.498378
#
# EPOCH 41: 	Trainning loss: 0.422	Validation loss: 0.498754
#
# EPOCH 42: 	Trainning loss: 0.421	Validation loss: 0.499124
#
# EPOCH 43: 	Trainning loss: 0.421	Validation loss: 0.499487
#
# EPOCH 44: 	Trainning loss: 0.420	Validation loss: 0.499842
#
# EPOCH 45: 	Trainning loss: 0.420	Validation loss: 0.500189
#
# EPOCH 46: 	Trainning loss: 0.420	Validation loss: 0.500529
#
# EPOCH 47: 	Trainning loss: 0.419	Validation loss: 0.500861
#
# EPOCH 48: 	Trainning loss: 0.419	Validation loss: 0.501185
#
# EPOCH 49: 	Trainning loss: 0.418	Validation loss: 0.501501
#
# EPOCH 50: 	Trainning loss: 0.418	Validation loss: 0.501810
#
# EPOCH 51: 	Trainning loss: 0.418	Validation loss: 0.502110
#
# EPOCH 52: 	Trainning loss: 0.417	Validation loss: 0.502403
#
# EPOCH 53: 	Trainning loss: 0.417	Validation loss: 0.502689
#
# EPOCH 54: 	Trainning loss: 0.417	Validation loss: 0.502967
#
# EPOCH 55: 	Trainning loss: 0.417	Validation loss: 0.503238
#
# EPOCH 56: 	Trainning loss: 0.416	Validation loss: 0.503502
#
# EPOCH 57: 	Trainning loss: 0.416	Validation loss: 0.503759
#
# EPOCH 58: 	Trainning loss: 0.416	Validation loss: 0.504009
#
# EPOCH 59: 	Trainning loss: 0.416	Validation loss: 0.504253
#
# EPOCH 60: 	Trainning loss: 0.416	Validation loss: 0.504490
#
# EPOCH 61: 	Trainning loss: 0.415	Validation loss: 0.504722
#
# EPOCH 62: 	Trainning loss: 0.415	Validation loss: 0.504947
#
# EPOCH 63: 	Trainning loss: 0.415	Validation loss: 0.505166
#
# EPOCH 64: 	Trainning loss: 0.415	Validation loss: 0.505380
#
# EPOCH 65: 	Trainning loss: 0.415	Validation loss: 0.505589
#
# EPOCH 66: 	Trainning loss: 0.415	Validation loss: 0.505792
#
# EPOCH 67: 	Trainning loss: 0.415	Validation loss: 0.505989
#
# EPOCH 68: 	Trainning loss: 0.414	Validation loss: 0.506182
#
# EPOCH 69: 	Trainning loss: 0.414	Validation loss: 0.506370
#
# EPOCH 70: 	Trainning loss: 0.414	Validation loss: 0.506553
#
# EPOCH 71: 	Trainning loss: 0.414	Validation loss: 0.506732
#
# EPOCH 72: 	Trainning loss: 0.414	Validation loss: 0.506906
#
# EPOCH 73: 	Trainning loss: 0.414	Validation loss: 0.507076
#
# EPOCH 74: 	Trainning loss: 0.414	Validation loss: 0.507241
#
# EPOCH 75: 	Trainning loss: 0.414	Validation loss: 0.507403
#
# EPOCH 76: 	Trainning loss: 0.414	Validation loss: 0.507561
#
# EPOCH 77: 	Trainning loss: 0.413	Validation loss: 0.507715
#
# EPOCH 78: 	Trainning loss: 0.413	Validation loss: 0.507865
#
# EPOCH 79: 	Trainning loss: 0.413	Validation loss: 0.508011
#
# EPOCH 80: 	Trainning loss: 0.413	Validation loss: 0.508154
#
# EPOCH 81: 	Trainning loss: 0.413	Validation loss: 0.508294
#
# EPOCH 82: 	Trainning loss: 0.413	Validation loss: 0.508431
#
# EPOCH 83: 	Trainning loss: 0.413	Validation loss: 0.508564
#
# EPOCH 84: 	Trainning loss: 0.413	Validation loss: 0.508694
#
# EPOCH 85: 	Trainning loss: 0.413	Validation loss: 0.508821
#
# EPOCH 86: 	Trainning loss: 0.413	Validation loss: 0.508946
#
# EPOCH 87: 	Trainning loss: 0.413	Validation loss: 0.509067
#
# EPOCH 88: 	Trainning loss: 0.413	Validation loss: 0.509186
#
# EPOCH 89: 	Trainning loss: 0.413	Validation loss: 0.509302
#
# EPOCH 90: 	Trainning loss: 0.413	Validation loss: 0.509415
#
# EPOCH 91: 	Trainning loss: 0.413	Validation loss: 0.509526
#
# EPOCH 92: 	Trainning loss: 0.413	Validation loss: 0.509635
#
# EPOCH 93: 	Trainning loss: 0.413	Validation loss: 0.509741
#
# EPOCH 94: 	Trainning loss: 0.412	Validation loss: 0.509844
#
# EPOCH 95: 	Trainning loss: 0.412	Validation loss: 0.509946
#
# EPOCH 96: 	Trainning loss: 0.412	Validation loss: 0.510045
#
# EPOCH 97: 	Trainning loss: 0.412	Validation loss: 0.510142
#
# EPOCH 98: 	Trainning loss: 0.412	Validation loss: 0.510237
#
# EPOCH 99: 	Trainning loss: 0.412	Validation loss: 0.510330
#
# EPOCH 100: 	Trainning loss: 0.412	Validation loss: 0.510421

# %% [markdown]
# # Virtualize data

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epochs', ylabel='Loss', title='Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epochs', ylabel='Loss', title='Validation Loss')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epochs', ylabel='Accuracy', title='Training Accuracy')

ax[1, 1].plot(val_accs, 'orange')
ax[1, 1].set(xlabel='Epochs', ylabel='Accuracy', title='Training Accuracy')
# Out:
# [Text(0.5, 0, 'Epochs'),
#  Text(0, 0.5, 'Accuracy'),
#  Text(0.5, 1.0, 'Training Accuracy')]

# %% [markdown]
# # Testing model
# Sử dụng bộ trọng số mô hình tìm được sau quá trình huấn luyện, ta đánh giá độ chính xác của mô hình trên hai tập val và test:

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy(X_test, y_test, theta)

print('Evaluation on validation and test set:')
print(f'Validation set accuracy: {val_set_acc:.3f}')
print(f'Test set accuracy: {test_set_acc:.3f}')
# Out:
# Evaluation on validation and test set:
# Validation set accuracy: 0.777
# Test set accuracy: 0.775
